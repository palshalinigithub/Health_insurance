# %%
#import library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression 
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# read dataset
df=pd.read_excel("Health_insurance_cost.xlsx")
df
# Out:
#        age  gender     BMI  Children smoking_status   location  \
# 0     19.0  female     NaN         0            yes  southwest
# 1     18.0    male  33.770         1             no  southeast
# 2     28.0    male  33.000         3             no  southeast
# 3     33.0    male  22.705         0             no  northwest
# 4     32.0    male  28.880         0             no  northwest
# ...    ...     ...     ...       ...            ...        ...
# 1333  50.0    male  30.970         3             no  northwest
# 1334  18.0  female  31.920         0             no  northeast
# 1335  18.0  female  36.850         0             no  southeast
# 1336  21.0  female  25.800         0             no  southwest
# 1337  61.0  female  29.070         0            yes  northwest
#
#       health_insurance_price
# 0                16884.92400
# 1                 1725.55230
# 2                 4449.46200
# 3                21984.47061
# 4                 3866.85520
# ...                      ...
# 1333             10600.54830
# 1334              2205.98080
# 1335              1629.83350
# 1336              2007.94500
# 1337             29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#     age  gender     BMI  Children smoking_status   location  \
# 0  19.0  female     NaN         0            yes  southwest
# 1  18.0    male  33.770         1             no  southeast
# 2  28.0    male  33.000         3             no  southeast
# 3  33.0    male  22.705         0             no  northwest
# 4  32.0    male  28.880         0             no  northwest
#
#    health_insurance_price
# 0             16884.92400
# 1              1725.55230
# 2              4449.46200
# 3             21984.47061
# 4              3866.85520

# %%
df.tail()
# Out:
#        age  gender    BMI  Children smoking_status   location  \
# 1333  50.0    male  30.97         3             no  northwest
# 1334  18.0  female  31.92         0             no  northeast
# 1335  18.0  female  36.85         0             no  southeast
# 1336  21.0  female  25.80         0             no  southwest
# 1337  61.0  female  29.07         0            yes  northwest
#
#       health_insurance_price
# 1333              10600.5483
# 1334               2205.9808
# 1335               1629.8335
# 1336               2007.9450
# 1337              29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isnull().sum()
# Out:
# age                       28
# gender                     0
# BMI                       23
# Children                   0
# smoking_status             0
# location                   0
# health_insurance_price     2
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# age                       2.092676
# gender                    0.000000
# BMI                       1.718984
# Children                  0.000000
# smoking_status            0.000000
# location                  0.000000
# health_insurance_price    0.149477
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     1310 non-null   float64
#  1   gender                  1338 non-null   object
#  2   BMI                     1315 non-null   float64
#  3   Children                1338 non-null   int64
#  4   smoking_status          1338 non-null   object
#  5   location                1338 non-null   object
#  6   health_insurance_price  1336 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          BMI     Children  health_insurance_price
# count  1310.000000  1315.000000  1338.000000             1336.000000
# mean     39.166412    30.638217     1.094918            13268.527719
# std      14.055378     6.110302     1.205493            12112.797724
# min      18.000000    15.960000     0.000000             1121.873900
# 25%      26.000000    26.210000     0.000000             4744.325050
# 50%      39.000000    30.305000     1.000000             9382.033000
# 75%      51.000000    34.580000     2.000000            16604.302645
# max      64.000000    53.130000     5.000000            63770.428010

# %%
df['BMI'].unique()
# Out:
# array([   nan, 33.77 , 33.   , 22.705, 28.88 , 25.74 , 33.44 , 27.74 ,
#        29.83 , 25.84 , 26.22 , 26.29 , 34.4  , 39.82 , 42.13 , 24.6  ,
#        42.75 , 18.6  , 23.87 , 45.9  , 21.5  , 30.305, 44.88 , 41.1  ,
#        40.37 , 28.49 , 33.55 , 40.375, 27.28 , 17.86 , 33.3  , 39.14 ,
#        21.945, 24.97 , 23.94 , 34.485, 21.8  , 23.3  , 36.96 , 21.28 ,
#        29.4  , 27.3  , 37.9  , 37.715, 23.76 , 25.52 , 27.61 , 27.06 ,
#        39.4  , 34.9  , 22.   , 30.36 , 27.8  , 53.13 , 39.71 , 32.87 ,
#        44.7  , 30.97 ])

# %% [markdown]
# ## dealing with missing value

# %%
newdf=df.fillna(df.mean())

# %%
newdf.isnull().sum()
# Out:
# age                       0
# gender                    0
# BMI                       0
# Children                  0
# smoking_status            0
# location                  0
# health_insurance_price    0
# dtype: int64

# %%
newdf.shape
# Out:
# (1338, 7)

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['age'],bins=20,kde_kws={'linewidth':3, 'color':'red'})
sns.distplot(newdf['age'],bins=20,kde_kws={'linewidth':3, 'color':'green'})
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['BMI'],bins=20,kde_kws={'linewidth':3, 'color':'red'})
sns.distplot(newdf['BMI'],bins=20,kde_kws={'linewidth':3, 'color':'green'})
# Out:
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x='age',data=newdf)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x='BMI',data=df)
# Out:
# <Axes: xlabel='BMI'>

# %%
sns.boxplot(x='BMI',data=newdf)
# Out:
# <Axes: xlabel='BMI'>

# %% [markdown]
# ## Removing outliers

# %%
Q1=newdf.BMI.quantile(0.25)
Q3=newdf.BMI.quantile(0.75)
IQR=Q3-Q1
print(IQR)
print(Q1)
print(Q3)
# Out:
# 8.114999999999998
# 26.315
# 34.43

# %%
# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify and remove outliers
filtered_data = newdf[(newdf['BMI'] >= lower_bound) & (newdf['BMI'] <= upper_bound)]

# %%
sns.boxplot(x='BMI',data=filtered_data)
# Out:
# <Axes: xlabel='BMI'>

# %% [markdown]
# ## Exploratory data analysis

# %%
sns.countplot(x='gender',data=newdf)
plt.title("distribution of gender")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x='smoking_status',data=newdf)
plt.title("distribution of smoker")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x='location',data=newdf)
plt.title("distribution of location")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(newdf['age'],color='g',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(newdf['BMI'],color='g',kde=True)
# Out:
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
sns.distplot(newdf['health_insurance_price'],color='g',kde=True)
# Out:
# <Axes: xlabel='health_insurance_price', ylabel='Density'>

# %%
newdf.loc[newdf['health_insurance_price']==newdf['health_insurance_price'].max(), 'age']
# Out:
# 543    54.0
# Name: age, dtype: float64

# %%
sns.catplot(x='smoking_status',kind='count',hue='gender',data=newdf[newdf.age==18])

# %%
sns.barplot(x='gender',y='health_insurance_price',hue='smoking_status',data=newdf[(newdf.age==18)])
# Out:
# <Axes: xlabel='gender', ylabel='health_insurance_price'>

# %%
y=newdf.groupby('location')['health_insurance_price'].max().sort_values()
y
# Out:
# location
# southwest    52590.82939
# northeast    58571.07448
# northwest    60021.39897
# southeast    63770.42801
# Name: health_insurance_price, dtype: float64

# %%
sns.barplot(x='location', y='health_insurance_price',data=newdf)
# Out:
# <Axes: xlabel='location', ylabel='health_insurance_price'>

# %%
sns.distplot(newdf[(newdf.BMI>=30)]['health_insurance_price'],color='r')
# Out:
# <Axes: xlabel='health_insurance_price', ylabel='Density'>

# %%
sns.distplot(newdf[(newdf.BMI<=30)]['health_insurance_price'],color='r')
# Out:
# <Axes: xlabel='health_insurance_price', ylabel='Density'>

# %% [markdown]
# ## Encoding

# %%
categoricalfeature=[features for features in newdf.columns if newdf[features].dtypes=='object']
categoricalfeature
# Out:
# ['gender', 'smoking_status', 'location']

# %%
from sklearn.preprocessing import OrdinalEncoder
orderen=OrdinalEncoder()
newdf[['gender', 'smoking_status', 'location']]=orderen.fit_transform(newdf[['gender', 'smoking_status', 'location']])
newdf
# Out:
#        age  gender        BMI  Children  smoking_status  location  \
# 0     19.0     0.0  30.638217         0             1.0       3.0
# 1     18.0     1.0  33.770000         1             0.0       2.0
# 2     28.0     1.0  33.000000         3             0.0       2.0
# 3     33.0     1.0  22.705000         0             0.0       1.0
# 4     32.0     1.0  28.880000         0             0.0       1.0
# ...    ...     ...        ...       ...             ...       ...
# 1333  50.0     1.0  30.970000         3             0.0       1.0
# 1334  18.0     0.0  31.920000         0             0.0       0.0
# 1335  18.0     0.0  36.850000         0             0.0       2.0
# 1336  21.0     0.0  25.800000         0             0.0       3.0
# 1337  61.0     0.0  29.070000         0             1.0       1.0
#
#       health_insurance_price
# 0                16884.92400
# 1                 1725.55230
# 2                 4449.46200
# 3                21984.47061
# 4                 3866.85520
# ...                      ...
# 1333             10600.54830
# 1334              2205.98080
# 1335              1629.83350
# 1336              2007.94500
# 1337             29141.36030
#
# [1338 rows x 7 columns]

# %%
newdf['location'].value_counts()
# Out:
# 2.0    364
# 3.0    325
# 1.0    325
# 0.0    324
# Name: location, dtype: int64

# %% [markdown]
# ## feature selection

# %%
newdf.corr()['health_insurance_price'].sort_values()
# Out:
# location                 -0.005162
# gender                    0.058559
# Children                  0.067468
# BMI                       0.194878
# age                       0.294497
# smoking_status            0.786014
# health_insurance_price    1.000000
# Name: health_insurance_price, dtype: float64

# %%
newdff=newdf.loc[:,['Children','BMI','age','smoking_status','health_insurance_price']]

# %% [markdown]
# ## split dataset

# %%
x=newdff.drop(['health_insurance_price'],axis=1)
y=newdff.health_insurance_price

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.transform(x_test)

# %% [markdown]
# ## Apply Algorithm

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred1=lr.predict(x_test)

# %%
svm=SVR()
svm.fit(x_train,y_train)
y_pred2=svm.predict(x_test)

# %%
gr=GradientBoostingRegressor()
gr.fit(x_train,y_train)
y_pred3=gr.predict(x_test)

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred4=rf.predict(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor
d=DecisionTreeRegressor()
d.fit(x_train,y_train)
y_pred5=d.predict(x_test)

# %%
df1=pd.DataFrame({'Actual':y_test,'lr':y_pred1,'svm':y_pred2,'gr':y_pred3,'rf':y_pred4,'d':y_pred5,})

# %%
df1
# Out:
#            Actual            lr          svm            gr            rf  \
# 764    9095.06825   8567.274988  9539.322805  10262.811875   9908.364706
# 887    5272.17580   7005.127780  9473.595658   5914.665692   4733.662667
# 890   29330.98315  36634.042307  9678.149242  27716.268263  28223.459307
# 1293   9301.89355   9434.005360  9567.924620   9649.137957   9864.140910
# 259   33750.29180  31974.629356  9687.339971  40106.723785  39075.006015
# ...           ...           ...          ...           ...           ...
# 109   47055.53210  39048.588918  9681.350197  46549.089404  47042.471930
# 575   12222.89830  11656.587148  9640.589784  11931.160351  12681.632390
# 535    6067.12675   7291.326932  9470.525736   6536.138117   5793.122998
# 543   63770.42801  40772.806836  9639.662090  47632.928707  47248.299857
# 846    9872.70100  12595.536006  9599.758234  10555.250599   9675.524138
#
#                d
# 764    9225.2564
# 887    4935.6198
# 890   28950.4692
# 1293   9225.2564
# 259   35491.6400
# ...          ...
# 109   46599.1084
# 575   11073.1760
# 535    5484.4673
# 543   48675.5177
# 846    9386.1613
#
# [268 rows x 6 columns]

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['lr'],label='lr')

# %%
plt.subplot(222)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['svm'],label='svm')

# %%
plt.subplot(223)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['gr'],label='gr')

# %%
plt.subplot(224)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['rf'],label='rf')

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['d'],label='d')

# %%
from sklearn import metrics

# %%
score1=print(round(metrics.r2_score(y_test,y_pred1),2))
score2=metrics.r2_score(y_test,y_pred2)
score3=metrics.r2_score(y_test,y_pred3)
score4=metrics.r2_score(y_test,y_pred4)
score5=metrics.r2_score(y_test,y_pred5)

print(score1,score2,score3,score4,score5)
# Out:
# 0.77
# None -0.06633163360899674 0.8663734997166385 0.8418774913012779 0.7278917194422073

# %%
s1=metrics.mean_absolute_error(y_test,y_pred1)
s2=metrics.mean_absolute_error(y_test,y_pred2)
s3=metrics.mean_absolute_error(y_test,y_pred3)
s4=metrics.mean_absolute_error(y_test,y_pred4)
s5=metrics.mean_absolute_error(y_test,y_pred5)


print(s1,s2,s3,s4,s5)
# Out:
# 4247.543399545755 8567.58989942887 2626.3911936805207 2667.9261605742445 3120.1332759850748

# %% [markdown]
# ## After analysis data  Gradientboosting Regressor gives me best predication
